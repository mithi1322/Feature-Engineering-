# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
# Answer:
'''
The wine quality dataset contains 12 features:
1. Fixed acidity
2. Volatile acidity
3. Citric acid
4. Residual sugar
5. Chlorides
6. Free sulfur dioxide
7. Total sulfur dioxide
8. Density
9. pH
10. Sulphates
11. Alcohol

The output variable is the quality rating of the wine, which ranges from 0 to 10. The importance of each feature in predicting the quality of wine can 
vary depending on the type of wine being analyzed (red or white). However, here is a general discussion of the importance of each feature:

1. Fixed acidity: In general, higher levels of fixed acidity are associated with better quality wine.

2. Volatile acidity: Lower levels of volatile acidity are associated with better quality wine.

3. Citric acid: Wines with higher levels of citric acid may taste fresher and more vibrant, and are generally associated with better quality.

4. Residual sugar: The ideal level of residual sugar depends on the type of wine and personal preference.

5. Chlorides: Wines with higher levels of chlorides may taste saltier and may have a longer shelf life, but excessive levels of chlorides can result in a metallic taste.

6. Free sulfur dioxide: Wines with higher levels of free sulfur dioxide may have a longer shelf life, but excessive levels can result in an unpleasant taste and aroma.

7. Total sulfur dioxide: higher levels of total sulfur dioxide can result in a longer shelf life, but excessive levels can result in an unpleasant taste and aroma.

8. Density: Higher densities may indicate higher alcohol and sugar content, but excessive levels can result in a heavy or syrupy texture.

9. pH: The ideal pH level depends on the type of wine and personal preference.

10. Sulphates: Wines with higher levels of sulphates may have a longer shelf life, but excessive levels can result in an unpleasant taste and aroma.

11. Alcohol: Higher levels of alcohol can result in a fuller body and more intense flavor, but excessive levels can result in a harsh taste and aroma.
'''
# Out:
# '\nThe wine quality dataset contains 12 features:\n1. Fixed acidity\n2. Volatile acidity\n3. Citric acid\n4. Residual sugar\n5. Chlorides\n6. Free sulfur dioxide\n7. Total sulfur dioxide\n8. Density\n9. pH\n10. Sulphates\n11. Alcohol\n\nThe output variable is the quality rating of the wine, which ranges from 0 to 10. The importance of each feature in predicting the quality of wine can \nvary depending on the type of wine being analyzed (red or white). However, here is a general discussion of the importance of each feature:\n\n1. Fixed acidity: In general, higher levels of fixed acidity are associated with better quality wine.\n\n2. Volatile acidity: Lower levels of volatile acidity are associated with better quality wine.\n\n3. Citric acid: Wines with higher levels of citric acid may taste fresher and more vibrant, and are generally associated with better quality.\n\n4. Residual sugar: The ideal level of residual sugar depends on the type of wine and personal preference.\n\n5. Chlori
# ...

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
# Answer:
'''
During the feature engineering process of the wine quality dataset, 
missing data were handled by imputing the median value for each feature with missing data. 
This imputation technique is called median imputation.

Advantages of median imputation:

1. It is a simple and fast method to handle missing data.
2. It preserves the distribution of the data, since it only replaces the missing value with a central tendency measure (i.e., the median).
3. It can be used with both continuous and categorical variables.

Disadvantages of median imputation:

1. It reduces the variability of the data, since it replaces missing values with a single value.
2. It may result in biased estimates, especially if the missing data are not missing at random.
3. It may not be appropriate for variables with a high percentage of missing data.
'''
# Out:
# '\nDuring the feature engineering process of the wine quality dataset, \nmissing data were handled by imputing the median value for each feature with missing data. \nThis imputation technique is called median imputation.\n\nAdvantages of median imputation:\n\n1. It is a simple and fast method to handle missing data.\n2. It preserves the distribution of the data, since it only replaces the missing value with a central tendency measure (i.e., the median).\n3. It can be used with both continuous and categorical variables.\n\nDisadvantages of median imputation:\n\n1. It reduces the variability of the data, since it replaces missing values with a single value.\n2. It may result in biased estimates, especially if the missing data are not missing at random.\n3. It may not be appropriate for variables with a high percentage of missing data.\n'

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
# Answer:
'''
There are many key factors that can affect students' performance in exams,such as Standard Lunch help students perform well in exam and 
parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam.

Analyzing these factors using statistical techniques can help identify which factors are most strongly correlated with 
exam performance and can be used to make predictions about future performance or to identify areas for improvement.
'''
# Out:
# "\nThere are many key factors that can affect students' performance in exams,such as Standard Lunch help students perform well in exam and \nparent's whose education is of associate's degree or master's degree their male child tend to perform well in exam.\n\nAnalyzing these factors using statistical techniques can help identify which factors are most strongly correlated with \nexam performance and can be used to make predictions about future performance or to identify areas for improvement.\n"

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
# Answer:
'''
Feature engineering is the process of selecting and transforming variables to improve the performance of a machine learning model. 
In the context of the student performance data set, we can use feature engineering to identify the most important variables that 
affect students' performance and to transform the variables to better represent the underlying patterns in the data.

The process of feature engineering in the context of the student performance data set involves exploring the relationships between the variables and the target variable, 
creating new variables that capture important information, transforming the existing variables to better represent the patterns in the data, 
and selecting the most important variables for the model.
'''
# Out:
# "\nFeature engineering is the process of selecting and transforming variables to improve the performance of a machine learning model. \nIn the context of the student performance data set, we can use feature engineering to identify the most important variables that \naffect students' performance and to transform the variables to better represent the underlying patterns in the data.\n\nThe process of feature engineering in the context of the student performance data set involves exploring the relationships between the variables and the target variable, \ncreating new variables that capture important information, transforming the existing variables to better represent the patterns in the data, \nand selecting the most important variables for the model.\n"

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

wine = pd.read_csv('winequality-red.csv')
print(wine.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.hist(bins=20, figsize=(20,15))
plt.show()

# %%
wine['total sulfur dioxide log'] = np.log(wine['total sulfur dioxide'])
wine['total sulfur dioxide log'].hist(bins=20)
plt.show()

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('winequality-red.csv')
X = df.drop('quality', axis=1)
y = df['quality']

# Standardize the features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Perform PCA with all features
pca = PCA()
pca.fit(X_std)

# Calculate the explained variance ratio for each principal component
variance_ratio = pca.explained_variance_ratio_

# Calculate the cumulative sum of the explained variance ratio
cumulative_variance_ratio = np.cumsum(variance_ratio)

# Find the minimum number of principal components required to explain 90% of the variance
n_components = np.argmax(cumulative_variance_ratio >= 0.9) + 1

print(f"Minimum number of principal components required to explain 90% of the variance: {n_components}")
# Out:
# Minimum number of principal components required to explain 90% of the variance: 7
